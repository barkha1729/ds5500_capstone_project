All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58200_000058_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58580_003294_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58529_001441_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58568_002209_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58187_003092_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58560_001856_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58527_002375_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58504_002631_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58311_002205_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58517_001943_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58226_001740_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58524_000212_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58524_003113_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58509_003605_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58177_004239_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58537_000757_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58422_001140_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58281_002521_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58329_002938_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58291_001415_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58198_003771_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58174_001792_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58564_000126_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58580_003294_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58508_001718_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58524_002909_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58216_001891_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58377_003872_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58538_002774_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58330_000759_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58281_000692_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58284_002768_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58213_004027_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58550_002742_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58511_000863_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58537_000757_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58418_002446_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58504_002063_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58504_003623_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58302_003012_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58504_002063_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58215_002887_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58341_002805_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58422_003849_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58517_003494_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58512_002068_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58565_003743_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58330_000759_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58224_001771_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58422_003849_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58257_001078_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58524_003049_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58520_002380_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58422_003849_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58418_002446_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58281_000692_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58377_003872_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58198_002514_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58273_003586_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58209_001445_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58571_002679_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58511_003245_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58507_003903_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58524_003049_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58544_002496_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58245_002594_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58211_003268_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58541_000795_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58529_001853_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58525_003852_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58530_001942_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58216_001939_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58520_002380_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58336_000203_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58524_002909_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58529_001853_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58512_002068_Sideline.mp4
# /kaggle/input/nfl-player-contact-detection/train/58567_004074_All29.mp4
# /kaggle/input/nfl-player-contact-detection/train/58418_000886_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58406_000188_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58491_000084_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58218_003210_Endzone.mp4
# /kaggle/input/nfl-player-contact-detection/train/58491_001948_Sideline.mp4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
# from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
from sklearn.metrics import adjusted_rand_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

# %%
train_tracking_path = "/kaggle/input/nfl-player-contact-detection/train_player_tracking.csv"
train_labels = "/kaggle/input/nfl-player-contact-detection/train_labels.csv"

# %%
tracking_schema = dtype = {'game_play':str,
                           'game_key':int,
                           'play_id':int,
                           'nfl_player_id':int,
                           'step':int,
                           'team':str,
                           'position':str,
                           'jersey_number':int,
                           'x_position':float,
                           'y_position':float,
                           'speed':float,
                           'distance':float,
                           'direction':float,
                           'orientation':float,
                           'acceleration':float,
                           'sa':float}

# %%
contact_schema = {'contact_id':str,
                  'game_play':str,
                  'step':int,
                  'nfl_player_id_1':int,
                  'nfl_player_id_2':int,
                  'contact':int}

# %%
class Preprocessor:
    
    def __init__(self, data_source_paths):
        self.data_source_paths = data_source_paths
        pass
    
    def read_csv(self, path, schema=None, date_col=["datetime"]):
        if schema:
            df = pd.read_csv(path, dtype=schema, parse_dates=date_col)
        else:
            df = pd.read_csv(path,parse_dates=date_col)
        return df
    
    def filter_contacts(self, df):
        df= df[df['contact']==1]
        return df.iloc[:1000,:]
    
    def remove_ground_contact(self,df):
        df.nfl_player_id_2 = pd.to_numeric(df.nfl_player_id_2.replace('G', 0))
        df['nfl_player_id_2'].drop(df[df['nfl_player_id_2'] == 0].index, inplace=True)
        return df
        
    def encode_categorical(self, df,   label_dict=None):
        df.team = df.team.replace({'home':1, 'away':-1})
        return df
    
    def join_tracking_data(self, contact_df, tracking_df):
        #fetched player 1 details
        contact_details_df = pd.merge(contact_df, tracking_df, how='inner', left_on = ['game_play', 'step', "nfl_player_id_1"], right_on = ['game_play', 'step', 'nfl_player_id'], suffixes=('','_P1'))
        selected_cols = ['contact_id', 'game_play', 'datetime', 'step', 'nfl_player_id_1',
       'nfl_player_id_2','team', 'position', 'jersey_number', 'x_position',
       'y_position', 'speed', 'distance', 'direction', 'orientation',
       'acceleration', 'sa']
        contact_details_df = contact_details_df[selected_cols]
                                      
        #fetched player 2 details
        contact_details_df = pd.merge(contact_details_df, tracking_df, how='inner', left_on = ['game_play', 'step', "nfl_player_id_2"], right_on = ['game_play', 'step', 'nfl_player_id'], suffixes=('_P1','_P2'))
        selected_cols = [
                 #     'contact_id', 'game_play', 
                 'nfl_player_id_1','nfl_player_id_2',
                #       'position_P1','position_P2','jersey_number_P1','jersey_number_P2',
                 'team_P1',  'x_position_P1', 'y_position_P1', 'speed_P1', 'distance_P1','direction_P1', 'orientation_P1', 'acceleration_P1', 'sa_P1',
                 'team_P2',  'x_position_P2', 'y_position_P2','speed_P2', 'distance_P2', 'direction_P2', 'orientation_P2','acceleration_P2', 'sa_P2']
        contact_details_df = contact_details_df[selected_cols]
        return contact_details_df

# %%
processor = Preprocessor([train_tracking_path,train_labels])

# %%
tracking_df = processor.read_csv(train_tracking_path, tracking_schema)
tracking_df.head()
# Out:
#       game_play  game_key  play_id  nfl_player_id  \
# 0  58580_001136     58580     1136          44830
# 1  58580_001136     58580     1136          47800
# 2  58580_001136     58580     1136          52444
# 3  58580_001136     58580     1136          46206
# 4  58580_001136     58580     1136          52663
#
#                           datetime  step  team position  jersey_number  \
# 0 2021-10-10 21:08:20.900000+00:00  -108  away       CB             22
# 1 2021-10-10 21:08:20.900000+00:00  -108  away       DE             97
# 2 2021-10-10 21:08:20.900000+00:00  -108  away       FS             29
# 3 2021-10-10 21:08:20.900000+00:00  -108  home       TE             86
# 4 2021-10-10 21:08:20.900000+00:00  -108  away      ILB             48
#
#    x_position  y_position  speed  distance  direction  orientation  \
# 0       61.59       42.60   1.11      0.11     320.33       263.93
# 1       59.48       26.81   0.23      0.01     346.84       247.16
# 2       72.19       31.46   0.61      0.06      11.77       247.69
# 3       57.37       22.12   0.37      0.04     127.85        63.63
# 4       63.25       27.50   0.51      0.05     183.62       253.71
#
#    acceleration    sa
# 0          0.71 -0.64
# 1          1.29  0.90
# 2          0.63 -0.33
# 3          0.69  0.62
# 4          0.31  0.31

# %%
contact_df = processor.read_csv(train_labels)
contact_df.head()
# Out:
#                    contact_id     game_play                         datetime  \
# 0  58168_003392_0_38590_43854  58168_003392 2020-09-11 03:01:48.100000+00:00
# 1  58168_003392_0_38590_41257  58168_003392 2020-09-11 03:01:48.100000+00:00
# 2  58168_003392_0_38590_41944  58168_003392 2020-09-11 03:01:48.100000+00:00
# 3  58168_003392_0_38590_42386  58168_003392 2020-09-11 03:01:48.100000+00:00
# 4  58168_003392_0_38590_47944  58168_003392 2020-09-11 03:01:48.100000+00:00
#
#    step  nfl_player_id_1 nfl_player_id_2  contact
# 0     0            38590           43854        0
# 1     0            38590           41257        0
# 2     0            38590           41944        0
# 3     0            38590           42386        0
# 4     0            38590           47944        0

# %%
contact_df = processor.filter_contacts(contact_df)
# replacing 'G' with 0
contact_df = processor.remove_ground_contact(contact_df)
contact_df.shape
# Out:
# (1000, 7)

# %%
#replace home with 1 and away with -1
tracking_df= processor.encode_categorical(tracking_df)
tracking_df.shape 
#(13,53,053, 17)
# Out:
# (1353053, 17)

# %%
contact_details_df = processor.join_tracking_data( contact_df, tracking_df)
print(contact_details_df.shape )
contact_details_df.head()
# Out:
# (746, 20)
#    nfl_player_id_1  nfl_player_id_2  team_P1  x_position_P1  y_position_P1  \
# 0            41944            42565       -1          41.78          22.56
# 1            41944            42565       -1          41.67          22.38
# 2            37084            38567       -1          41.54          20.00
# 3            43854            46445       -1          41.49          16.61
# 4            41944            42565       -1          41.58          22.20
#
#    speed_P1  distance_P1  direction_P1  orientation_P1  acceleration_P1  \
# 0      1.43         0.15        217.49          287.37             1.56
# 1      1.83         0.21        212.07          288.29             1.55
# 2      1.07         0.11        254.82          257.32             0.41
# 3      1.23         0.12        234.00          312.29             1.08
# 4      2.00         0.20        208.64          295.28             1.38
#
#    sa_P1  team_P2  x_position_P2  y_position_P2  speed_P2  distance_P2  \
# 0   1.51        1          40.70          23.02      1.66         0.17
# 1   1.47        1          40.68          22.85      1.80         0.18
# 2   0.40        1          40.82          19.54      1.72         0.20
# 3   0.37        1          40.67          17.42      1.63         0.16
# 4   1.23        1          40.65          22.66      1.91         0.19
#
#    direction_P2  orientation_P2  acceleration_P2  sa_P2
# 0        189.20          109.99             1.29   1.28
# 1        188.04          117.12             0.84   0.84
# 2        125.75          103.92             1.07   1.05
# 3        155.99          114.56             0.33   0.16
# 4        187.69          124.81             0.38   0.38

# %% [markdown]
# **Cheking with an example**

# %%
tracking_df[(tracking_df['nfl_player_id']==41944) & (tracking_df['game_play']=="58168_003392")& (tracking_df['step']==3)]
# Out:
#             game_play  game_key  play_id  nfl_player_id  \
# 1081081  58168_003392     58168     3392          41944
#
#                                 datetime  step  team position  jersey_number  \
# 1081081 2020-09-11 03:01:48.400000+00:00     3    -1       DT             92
#
#          x_position  y_position  speed  distance  direction  orientation  \
# 1081081       41.78       22.56   1.43      0.15     217.49       287.37
#
#          acceleration    sa
# 1081081          1.56  1.51

# %%
# tracking_df[(tracking_df['nfl_player_id']==42565)].sort_values(by='datetime').iloc[185:]
tracking_df[(tracking_df['nfl_player_id']==42565) & (tracking_df['game_play']=="58168_003392")& (tracking_df['step']==3)]
# Out:
#             game_play  game_key  play_id  nfl_player_id  \
# 1081085  58168_003392     58168     3392          42565
#
#                                 datetime  step  team position  jersey_number  \
# 1081085 2020-09-11 03:01:48.400000+00:00     3     1        C             62
#
#          x_position  y_position  speed  distance  direction  orientation  \
# 1081085        40.7       23.02   1.66      0.17      189.2       109.99
#
#          acceleration    sa
# 1081085          1.29  1.28

# %%
x = np.array([41.78,40.7 ])
y = np.array([22.56,23.02 ])

plt.scatter(x, y)
plt.show()

# %%
class FeatureEngineer:
    def calculate_angle_of_collision(self, x):
        theta = abs(x['orientation_P1']-x['orientation_P2'])
        return theta
    
    def calculate_torque_per_unit_mass(self, x):
        theta =x['angle_of_collision']
        torque = x['force_per_unit_mass']*x['player_sensor_distance']*math.sin(theta)
        return torque
    
    def calculate_force_per_unit_mass(self, x):
        a_x = x['acceleration_P1']*math.cos(x['orientation_P1']) - x['acceleration_P2']*math.cos(x['orientation_P2'])
        a_y = x['acceleration_P1']*math.sin(x['orientation_P1']) - x['acceleration_P2']*math.sin(x['orientation_P2'])
        return math.sqrt((a_x**2)+(a_y**2))
    
    def calculate_relative_valocity(self, x):
        v_x = x['speed_P1']*math.cos(x['orientation_P1']) - x['speed_P2']*math.cos(x['orientation_P2'])
        v_y = x['speed_P1']*math.sin(x['orientation_P1']) - x['speed_P2']*math.sin(x['orientation_P2'])
        return math.sqrt((v_x**2)+(v_y**2)) 
    
    def calculate_distance(self, x):
        dx = x['x_position_P1'] - x['x_position_P2']
        dy = x['y_position_P1'] - x['y_position_P2']
        return math.sqrt((dx**2)+(dy**2)) 
    
    def get_cluster_df(self, contact_details_df):
        cluster_df = pd.DataFrame()
        cluster_df['diff_team_collision'] = (contact_details_df['team_P1']*contact_details_df['team_P2']).apply(lambda x: 1 if x==-1 else 0)
        cluster_df['relative_velocity'] = contact_details_df.apply(self.calculate_relative_valocity, axis =1)
        cluster_df['player_sensor_distance'] = contact_details_df.apply(self.calculate_distance, axis =1)
        cluster_df['force_per_unit_mass'] =contact_details_df.apply(self.calculate_force_per_unit_mass,axis=1)
        cluster_df['angle_of_collision'] = contact_details_df.apply(self.calculate_angle_of_collision,axis=1)
        cluster_df['angle_of_collision'] = cluster_df['angle_of_collision'].apply(lambda x: 360-x if x>180 else x)
        cluster_df['torque_per_unit_mass'] = abs(cluster_df.apply(self.calculate_torque_per_unit_mass,axis=1))
        return cluster_df, list(cluster_df.columns)

# %%
feature_engineer = FeatureEngineer()
cluster_df, cluster_cols = feature_engineer.get_cluster_df(contact_details_df)

# %%
cluster_df[['angle_of_collision']].describe()
# Out:
#        angle_of_collision
# count          746.000000
# mean           109.678874
# std             50.966889
# min              0.510000
# 25%             69.657500
# 50%            117.045000
# 75%            154.695000
# max            179.990000

# %%
cluster_df.head()
# Out:
#    diff_team_collision  relative_velocity  player_sensor_distance  \
# 0                    1           2.057237                1.173882
# 1                    1           2.506132                1.095901
# 2                    1           2.695191                0.854400
# 3                    1           2.847312                1.152606
# 4                    1           1.567896                1.037545
#
#    force_per_unit_mass  angle_of_collision  torque_per_unit_mass
# 0             1.901563              177.38              2.216163
# 1             1.728085              171.17              1.891737
# 2             1.437510              153.40              0.629401
# 3             1.405428              162.27              1.438356
# 4             1.156009              170.47              0.880208

# %%
sns.pairplot(cluster_df, hue='diff_team_collision')

# %%
# plt.scatter(cluster_df['diff_team_collision'],cluster_df['player_sensor_distance'])

# %%
class Cluster:
    def __init__(self, df):
        self.cluster_df = df
        self.columns = list(df.columns)
        self.scaled_features=None
        self.scale()
    def scale(self):
        scaler = StandardScaler()
        self.scaled_features = scaler.fit_transform(self.cluster_df)
        self.sf_df = pd.DataFrame(self.scaled_features)
        return self.scaled_features
    def Kmeans(self, find_k=False):
        if find_k:
            kmeans_kwargs = {
                "init": "random",
                "n_init": 10,
                "max_iter": 300,
                "random_state": 42,}
            # A list holds the SSE values for each k
            sse = []
            for k in range(1, 11):
                kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
                kmeans.fit(self.scaled_features)
                sse.append(kmeans.inertia_)
            plt.style.use("fivethirtyeight")
            plt.plot(range(1, 11), sse)
            plt.xticks(range(1, 11))
            plt.xlabel("Number of Clusters")
            plt.ylabel("SSE")
            plt.show()
#             kl = KneeLocator( range(1, 11), sse, curve="convex", direction="decreasing")
#             k = kl.elbow
        else:
            kmeans = KMeans(n_clusters=3)
            kmeans.fit(self.scaled_features)
            kmeans_silhouette = silhouette_score( self.scaled_features, kmeans.labels_ ).round(2)
            print("kmeans_silhouette", kmeans_silhouette)
            df = self.cluster_df.copy()
            df['km_label'] = kmeans.labels_
            sns.scatterplot(data=df, x="force_per_unit_mass", y="angle_of_collision", hue="km_label", palette="deep")
            return kmeans.labels_, pd.DataFrame(kmeans.labels_).value_counts()
        return
            
        
    def DBScan(self,epsilon=2):
            
        dbscan = DBSCAN(eps=epsilon)
        dbscan.fit(self.scaled_features)
        df = self.cluster_df.copy()
        df['db_label'] = dbscan.labels_
        sns.scatterplot(data=df, x="force_per_unit_mass", y="angle_of_collision", hue="db_label", palette="deep")
        return dbscan.labels_, pd.DataFrame(dbscan.labels_).value_counts()
    
    def Hierarchical(self,n=2,find_n=False ):
        if find_n:
            linkage_data = linkage(self.scaled_features, method='ward', metric='euclidean')
            dendrogram(linkage_data)
            plt.show()
            return linkage_data
        else:
            hierarchical_cluster = AgglomerativeClustering(n_clusters=n, affinity='euclidean', linkage='ward')
            labels = hierarchical_cluster.fit_predict(self.scaled_features)
            df = self.cluster_df.copy()
            df['h_label'] = labels
            sns.scatterplot(data=df, x="force_per_unit_mass", y="angle_of_collision", hue="h_label",style="diff_team_collision", palette="deep")
            return labels, pd.DataFrame(labels).value_counts()

# %%
cluster = Cluster(cluster_df)
cluster.sf_df.describe()
# Out:
#                   0             1             2             3             4  \
# count  7.460000e+02  7.460000e+02  7.460000e+02  7.460000e+02  7.460000e+02
# mean   1.142964e-16  6.667291e-17 -2.190681e-16 -9.524702e-18  5.714821e-17
# std    1.000671e+00  1.000671e+00  1.000671e+00  1.000671e+00  1.000671e+00
# min   -5.370289e+00 -1.444158e+00 -2.071048e+00 -1.598703e+00 -2.143394e+00
# 25%    1.862097e-01 -7.359887e-01 -8.546592e-01 -7.786695e-01 -7.857695e-01
# 50%    1.862097e-01 -1.315162e-01 -7.065430e-02 -1.953870e-01  1.446246e-01
# 75%    1.862097e-01  5.232024e-01  7.364789e-01  5.447980e-01  8.838351e-01
# max    1.862097e-01  4.443712e+00  3.070976e+00  4.377113e+00  1.380471e+00
#
#                   5
# count  7.460000e+02
# mean   2.476422e-16
# std    1.000671e+00
# min   -1.116907e+00
# 25%   -7.133738e-01
# 50%   -2.404385e-01
# 75%    3.824191e-01
# max    5.193872e+00

# %%
cluster.Kmeans(True)

# %%
kmlabels, kmcount_freq = cluster.Kmeans()
kmcount_freq
# Out:
# kmeans_silhouette 0.31
# 2    499
# 1    222
# 0     25
# dtype: int64

# %%
dblabels, dbcount_freq = cluster.DBScan(100)
dbcount_freq
# Out:
# 0    746
# dtype: int64

# %%
hdata = cluster.Hierarchical(find_n=True)

# %%
hlabel, hfreq = cluster.Hierarchical(n=3)
hfreq
# Out:
# 0    572
# 1    149
# 2     25
# dtype: int64
